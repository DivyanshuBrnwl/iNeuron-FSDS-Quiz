# %% [markdown]
# 1. What does the function 'pd.DataFrame()' do in pandas?

# %% [markdown]
# Ans. Creates a dataframe

# %% [markdown]
# 2.What does the NumPy function 'np.arange(3, 7, 2)' return?

# %%
import numpy as np

# %%
np.arange(3, 7, 2)
# Out:
# array([3, 5])

# %% [markdown]
# 3. Which library can be used to create interactive visualizations in Python?

# %%
Ans. plotly

# %% [markdown]
# 4.
# What does the 'df.info()' function do in pandas?

# %% [markdown]
# 5.
# What does the 'np.mean()' function do in NumPy?

# %% [markdown]
# 6.
# In pandas, what does the 'df.loc[]' function do?

# %%
import pandas as pd

# %%
df = pd.read_csv('https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
df.loc[0:2, : ]
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[[0, 1, 2], :]
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[:, 'Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 151              113776
# 152          A.5. 11206
# 153            A/5. 851
# 154           Fa 265302
# 155            PC 17597
# Name: Ticket, Length: 156, dtype: object

# %%
df.loc[1:7, 'Name']
# Out:
# 1     Mrs. John Bradley (Florence Briggs Thayer)
# 2                                    Miss. Laina
# 3             Mrs. Jacques Heath (Lily May Peel)
# 4                              Mr. William Henry
# 5                                      Mr. James
# 6                                  Mr. Timothy J
# 7                          Master. Gosta Leonard
# Name: Name, dtype: object

# %%
df.loc[:, 'Name':'Ticket']
# Out:
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# 3             Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                              Mr. William Henry    male  35.0      0      0
# ..                                           ...     ...   ...    ...    ...
# 151                   Mrs. Thomas (Edith Wearne)  female  22.0      1      0
# 152                                  Mr. Alfonzo    male  55.5      0      0
# 153                            Mr. Austin Blyler    male  40.5      0      2
# 154                               Mr. Ole Martin    male   NaN      0      0
# 155                            Mr. Charles Duane    male  51.0      0      1
#
#                Ticket
# ...

# %%
df.loc[df.Sex=='male']
# Out:
#      PassengerId  Survived  Pclass         Lname                    Name  \
# 0              1         0       3        Braund         Mr. Owen Harris
# 4              5         0       3         Allen       Mr. William Henry
# 5              6         0       3         Moran               Mr. James
# 6              7         0       1      McCarthy           Mr. Timothy J
# 7              8         0       3       Palsson   Master. Gosta Leonard
# ..           ...       ...     ...           ...                     ...
# 150          151         0       2       Bateman       Rev. Robert James
# 152          153         0       3           Meo             Mr. Alfonzo
# 153          154         0       3  van Billiard       Mr. Austin Blyler
# 154          155         0       3         Olsen          Mr. Ole Martin
# 155          156         0       1      Williams       Mr. Charles Duane
#
#       Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# ...

# %%
df.iloc[0:2, :]
# Out:
#    PassengerId  Survived  Pclass    Lname  \
# 0            1         0       3   Braund
# 1            2         1       1  Cumings
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df.loc[0:2, :]
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
df[0:2]
# Out:
#    PassengerId  Survived  Pclass    Lname  \
# 0            1         0       3   Braund
# 1            2         1       1  Cumings
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %% [markdown]
# 7.
# Which of the following statements is true about the 'matplotlib' library?

# %% [markdown]
# Ans. matplotlib provides an object-oriented API

# %% [markdown]
# 8.
# What is the purpose of the 'np.zeros()' function in NumPy?

# %% [markdown]
# Ans. Creates an array filled with zeros

# %% [markdown]
# 9.
# What is the role of 'plt.xlabel()' in the context of matplotlib?

# %% [markdown]
# The 'plt.xlabel()' function in matplotlib is used to set the label for the x-axis in a plot or graph.

# %% [markdown]
# 10.
# Which of the following is true about the 'seaborn' library?

# %% [markdown]
# Seaborn' is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# 11.
# In pandas, what does the 'df.dropna()' function do?

# %% [markdown]
# The 'df.dropna()' function is used to remove missing values (NaN) from a DataFrame.

# %% [markdown]
# 12.
# What is the purpose of 'np.random.seed()' in NumPy?

# %% [markdown]
# The 'np.random.seed()' function in NumPy is used to set the random seed, which allows for reproducible random numbers to be generated.

# %% [markdown]
# 13.
# What does the 'df.describe()' function do in pandas?

# %% [markdown]
# The 'df.describe()' function generates descriptive statistics of the DataFrame, such as count, mean, standard deviation, minimum, and maximum values.

# %% [markdown]
# 14.
# What is the purpose of 'plt.subplot()' in matplotlib?

# %% [markdown]
# The 'plt.subplot()' function in matplotlib is used to create a subplot within a grid of plots.
